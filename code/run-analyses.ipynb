# %% [markdown]
# # Run Analyses of Canada-Wide GTFS Data
#
# Author: Kevin Dick
#
# The general analysis pipeline will first load the cleaned CSD spreadsheet containing IDs for those CSDs that have validated GTFS data. Thereafter, the archived GTFS data is converted into an SQLight database format that functions with the `gtfspy` library. We then iterate over all CSDs and extract summary statistics for their GTFS offerings. Finally, a number of correlation analyses are run using the Statistics Canada census data and the GTFS offerings in these regions.

# %%
import os
import pandas as pd
from gtfspy import import_gtfs
from gtfspy import gtfs, stats
from gtfspy import osm_transfers

# %%
# Load the cleaned dataset of CSD information
df_raw = pd.read_csv('../data/CSD-tabulation-cleaned.csv', encoding='latin1')
df_clean = df_raw[df_raw['Id'].notna()].reset_index()
df_clean.head(5)
# Out:
#    index           Id  GeographicCode GeographicName CSDType  \
# 0      0   Toronto-ON         3520005        Toronto    City
# 1      1  Montreal-QC         2466023       Montréal   Ville
# 2      2   Calgary-AB         4806016        Calgary    City
# 3      3    Ottawa-ON         3506008         Ottawa    City
# 4      4  Edmonton-AB         4811061       Edmonton    City
#
#   ProvinceTerritory  GeographicCodeProvinceTerritory  \
# 0           Ontario                               35
# 1            Quebec                               24
# 2           Alberta                               48
# 3           Ontario                               35
# 4           Alberta                               48
#
#    GeographicCodeCensusDivision  Population2016  Population2011  ...  \
# 0                          3520         2731571         2615060  ...
# 1                          2466         1704694         1649519  ...
# 2                          4806         1239220         1096833  ...
# 3                          3506          934243          883391  ...
# 4                          4811          932546          812201  ...
#
#    TotalPrivateDwellings2016  TotalPrivateDwellings2011  \
# 0                    1179057                    1107851
# 1                     843872                     813819
# 2                     489650                     445848
# 3                     395985                     370217
# 4                     387950                     348672
#
#    TotalPrivateDwellingsPercentChange  \
# 0                                 6.4
# 1                                 3.7
# 2                                 9.8
# 3                                 7.0
# 4                                11.3
#
#    PrivateDwellingsOccupiedByUsualResidents2016  \
# 0                                       1112929
# 1                                        779802
# 2                                        466725
# 3                                        373756
# 4                                        360828
#
#    PrivateDwellingsOccupiedByUsualResidents2011  \
# 0                                       1047877
# 1                                        759946
# 2                                        423417
# 3                                        353244
# 4                                        324756
#
#    PrivateDwellingsOccupiedByUsualResidentsPercentChange  \
# 0                                                6.2
# 1                                                2.6
# 2                                               10.2
# 3                                                5.8
# 4                                               11.1
#
#    LandAreaInSquareKilometres2016  PopulationDensityPerSquareKilometre2016  \
# 0                          630.20                                   4334.4
# 1                          365.65                                   4662.1
# 2                          825.56                                   1501.1
# 3                         2790.30                                    334.8
# 4                          685.25                                   1360.9
#
#    NationalPopulationRank2016  ProvincialTerritorialPopulationRank2016
# 0                           1                                        1
# 1                           2                                        1
# 2                           3                                        1
# 3                           4                                        2
# 4                           5                                        2
#
# [5 rows x 21 columns]

# %%
# Turn all cleaned CSDs into an SQL database variant
base_gtfs_dir = '../data/CSDs-StaticGTFS/'
db_gtfs_dir   = '../data/sqlite-db/'
for index, row in df_clean.iterrows():
    csd_id = row['Id']
    print(f"{'-'*30} Processing {csd_id}")
    imported_database_path = os.path.join(db_gtfs_dir, csd_id)
    if os.path.exists(imported_database_path): # skip those that have already been processed
        print('Already Processed; skipping...\n\n')
        continue

    import_gtfs.import_gtfs([f"{base_gtfs_dir}/{csd_id}/Static_GTFS/{csd_id}.zip"],  # input: list of GTFS zip files (or directories)
                            imported_database_path,  # output: where to create the new sqlite3 database
                            print_progress=True,  # whether to print progress when importing data
                            location_name=csd_id)

    # Now you can access the imported database using a GTFS-object as an interface:
    G = gtfs.GTFS(imported_database_path)
    print(f"{'-'*30} Finished: {G.get_location_name()}\n\n")
# Out:
# ------------------------------ Processing Toronto-ON
# Beginning AgencyLoader
# Importing agency.txt into agencies for
# Indexing agencies
# Post-import agency.txt into agencies
# Beginning RouteLoader
# Importing routes.txt into routes for
# Indexing routes
# Beginning MetadataLoader
# Indexing metadata
# Beginning CalendarLoader
# Importing calendar.txt into calendar for
# Indexing calendar
# Beginning CalendarDatesLoader
# Importing calendar_dates.txt into calendar_dates for
# Beginning ShapeLoader
# Importing shapes.txt into shapes for
# Indexing shapes
# Post-import shapes.txt into shapes
# Beginning FeedInfoLoader
# feed_info.txt  missing in  {'zipfile': '../data/CSDs-StaticGTFS//Toronto-ON/Static_GTFS/Toronto-ON.zip', 'zip_commonprefix': ''}
# Beginning StopLoader
# Importing stops.txt into stops for
# Indexing stops
# Post-import stops.txt into stops
# Beginning TransfersLoader
# transfers.txt  missing in  {'zipfile': '../data/CSDs-StaticGTFS//Toronto-ON/Static_GTFS/Toronto-ON.zip', 'zip_commonprefix': ''}
# Beginning StopDistancesLoader
# Post-import None into stop_distances
# Calculating straight-line transfer distances
# Copying information from transfers to stop_distances.
# Beginning TripLoader
# Importing trips.txt into trips for
# Indexing trips
# Beginning StopTimesLoader
# Importing stop_times.txt into stop_times for
# Indexing stop_times
# Post-import stop_times.txt into stop_times
#  Shape trip breakpoints: 413 bad fits
#  Shape trip breakpoints: 31914 no shape fits
# Beginning FrequenciesLoader
# frequencies.txt  missing in  {'zipfile': '../data/CSDs-StaticGTFS//Toronto-ON/Static_GTFS/Toronto-ON.zip', 'zip_commonprefix': ''}
# Post-import frequencies.txt into frequencies
# Beginning DayLoader
# Indexing days
# Post-import None into days
# Beginning DayTripsMaterializer
# Indexing day_trips2
# updating trips travel times
# Vacuuming...
# Analyzing...
# ------------------------------ Finished: Toronto-ON
#
#
# ------------------------------ Processing Montreal-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Calgary-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Ottawa-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Edmonton-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Mississauga-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Winnipeg-MN
# Already Processed; skipping...
#
#
# ------------------------------ Processing Vancouver-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Brampton-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Hamilton-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Quebec-City-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Surrey-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Laval-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Halifax-NS
# Already Processed; skipping...
#
#
# ------------------------------ Processing Vaughan-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Gatineau-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Saskatoon-SK
# Already Processed; skipping...
#
#
# ------------------------------ Processing Windsor-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Regina-SK
# Already Processed; skipping...
#
#
# ------------------------------ Processing Richmond-Hill-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Oakville-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Burlington-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Greater-Sudbury-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Levis-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Barrie-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Abbotsford-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Coquitlam-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Guelph-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Ajax-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Terrebone-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Milton-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Thunder-Bay-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Red-Deer-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Strathcona-County-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Brantford-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Saint-Jean-sur-Richelieu-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Lethbridge-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Pickering-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Nanaimo-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Kamloops-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Victoria-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Repentigny-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Chilliwack-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Saint-Jerome-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Wood-Buffalo-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing StAlbert-Alberta
# Already Processed; skipping...
#
#
# ------------------------------ Processing Grande-Prairie-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Airdrie-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Port-Coquitlam-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Aurora-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing North-Vancouver-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Chateauguay-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Cornwall-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Georgina-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Salaberry-de-Valleyfield-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Rocky-View-County-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Mission-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Vauldreuil-Dorion-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Prince-Albert-SK
# Already Processed; skipping...
#
#
# ------------------------------ Processing Langford-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Sorel-Tracy-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Spruce-Grove-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Penticton-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Port-Moody-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing West-Kelowna-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Campbell-River-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Cote-Saint-Luc-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Parkland-County-AB
# Already Processed; skipping...
#
#
# ------------------------------ Processing Pointe-Claire-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing LaSalle-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Sainte-Julie-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing North-Cowichan-BC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Grimsby-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Boisbriand-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Sainte-Therese-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Sept-Iies-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Beloeil-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing LAssomption-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Scugog-ON
# Already Processed; skipping...
#
#
# ------------------------------ Processing Varennes-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Saint-Lin-Laurentides-QC
# Already Processed; skipping...
#
#
# ------------------------------ Processing Fort-St-John-BC
# Already Processed; skipping...

# %%
# The final number of CSDs with validated GTFS data 
df_clean.shape
# Out:
# (82, 21)

# %%
# Iterate over all CSDs for which the sqlite-db was successfully created
# Load the GTFS data into an object from which to extract various summary statistics
n_routes  = []
n_stops   = []
n_trips   = []
n_days    = []
height_km = []
width_km  = []
ut_start  = []
ut_end    = []

db_gtfs_dir   = '../data/sqlite-db/'
for index, row in df_clean.iterrows():
    csd_id = row['Id']
    print(f"{'-'*30} getting statistics for {csd_id}")

    imported_database_path = os.path.join(db_gtfs_dir, csd_id)
    G = gtfs.GTFS(imported_database_path)

    stats = G.get_stats()
    print(stats)
    n_routes.append(stats['n_routes'])
    n_stops.append(stats['n_stops'])
    n_trips.append(stats['n_trips'])
    n_days.append(stats['n_days'])
    height_km.append(stats['height_km'])
    width_km.append(stats['width_km'])
    ut_start.append(stats['start_time_ut'])
    ut_end.append(stats['end_time_ut'])

# Append all data as new columns to final dataframe
df_all = df_clean.copy()
df_all['n_routes'] = n_routes
df_all['n_stops'] = n_stops
df_all['n_trips'] = n_trips
df_all['n_days'] = n_days
df_all['height_km'] = height_km
df_all['width_km'] = width_km
df_all['ut_start'] = ut_start
df_all['ut_end'] = ut_end
df_all.head()
# Out:
# ------------------------------ getting statistics for Toronto-ON
# {'n_agencies': 1, 'n_routes': 188, 'n_stops': 9464, 'n_stop_times': 4242313, 'n_trips': 123210, 'n_calendar': 6, 'n_shapes': 318007, 'n_calendar_dates': 2, 'n_days': 1439969, 'n_stop_distances': 493466, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'TTC', 'lat_min': 43.591811, 'lat_10': 43.6494352, 'lat_median': 43.719038, 'lat_90': 43.7987479, 'lat_max': 43.909707, 'lon_min': -79.649908, 'lon_10': -79.5459255, 'lon_median': -79.39900549999999, 'lon_90': -79.25116630000001, 'lon_max': -79.123111, 'height_km': 35.388020845218215, 'width_km': 58.64277379142436, 'start_time_ut': 1602388800, 'end_time_ut': 1606035600, 'start_date': '2020-10-11', 'end_date': '2020-11-21', 'max_activity_date': '2020-10-13', 'max_activity_hour': 8, 'fleet_size_route_based': '0:85 1:42 3:977', 'fleet_size_max_movement': '0:117 1:78 3:1105', 'routes__type__dist': '0:10 1:4 3:174', 'calendar_dates__exception_type__dist': '1:1 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:9464', 'latest_feed_start_date': '2020-10-11', 'earliest_feed_end_date': '2020-11-21'}
# ------------------------------ getting statistics for Montreal-QC
# {'n_agencies': 1, 'n_routes': 219, 'n_stops': 9034, 'n_stop_times': 7369306, 'n_trips': 203003, 'n_calendar': 140, 'n_shapes': 202409, 'n_calendar_dates': 78, 'n_days': 2938442, 'n_stop_distances': 687740, 'n_frequencies': 1290, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Société de transport de Montréal', 'lat_min': 45.402668, 'lat_10': 45.444934599999996, 'lat_median': 45.5147925, 'lat_90': 45.61099, 'lat_max': 45.701116, 'lon_min': -73.956204, 'lon_10': -73.7995859, 'lon_median': -73.61948749999999, 'lon_90': -73.54449299999999, 'lon_max': -73.480581, 'height_km': 33.22307938827096, 'width_km': 52.94611016956902, 'start_time_ut': 1641186000, 'end_time_ut': 1655107200, 'start_date': '2022-01-03', 'end_date': '2022-06-12', 'max_activity_date': '2022-01-07', 'max_activity_hour': 7, 'fleet_size_route_based': '1:68 3:1162', 'fleet_size_max_movement': '1:60 3:945', 'routes__type__dist': '1:4 3:215', 'calendar_dates__exception_type__dist': '2:78', 'frequencies__exact_times__dist': '0:1290', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': '0:8833 1:67 2:134', 'latest_feed_start_date': '2022-01-03', 'earliest_feed_end_date': '2022-06-12'}
# ------------------------------ getting statistics for Calgary-AB
# {'n_agencies': 1, 'n_routes': 275, 'n_stops': 6193, 'n_stop_times': 738649, 'n_trips': 23433, 'n_calendar': 11, 'n_shapes': 384904, 'n_calendar_dates': 8, 'n_days': 412124, 'n_stop_distances': 267112, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'Calgary Transit', 'lat_min': 50.854661, 'lat_10': 50.9193624, 'lat_median': 51.052288, 'lat_90': 51.1430426, 'lat_max': 51.184083, 'lon_min': -114.269483, 'lon_10': -114.18355960000001, 'lon_median': -114.070587, 'lon_90': -113.9574126, 'lon_max': -113.821508, 'height_km': 36.671089296101876, 'width_km': 49.86834888811668, 'start_time_ut': 1652076000, 'end_time_ut': 1656324000, 'start_date': '2022-05-09', 'end_date': '2022-06-26', 'max_activity_date': '2022-05-13', 'max_activity_hour': 8, 'fleet_size_route_based': '0:22 3:347', 'fleet_size_max_movement': '0:36 3:432', 'routes__type__dist': '0:2 3:273', 'calendar_dates__exception_type__dist': '1:2 2:6', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': ':1', 'stops__location_type__dist': '0:6193', 'latest_feed_start_date': '2022-05-09', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Ottawa-ON
# {'n_agencies': 1, 'n_routes': 191, 'n_stops': 5811, 'n_stop_times': 1110312, 'n_trips': 29548, 'n_calendar': 16, 'n_shapes': 266545, 'n_calendar_dates': 162, 'n_days': 387026, 'n_stop_distances': 276538, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'OC Transpo', 'lat_min': 45.130139, 'lat_10': 45.275538, 'lat_median': 45.372485, 'lat_90': 45.46178, 'lat_max': 45.519695, 'lon_min': -76.042785, 'lon_10': -75.889268, 'lon_median': -75.69305, 'lon_90': -75.50127, 'lon_max': -75.342688, 'height_km': 43.365175555464354, 'width_km': 77.9344415458984, 'start_time_ut': 1651809600, 'end_time_ut': 1656230400, 'start_date': '2022-05-06', 'end_date': '2022-06-25', 'max_activity_date': '2022-05-06', 'max_activity_hour': 8, 'fleet_size_route_based': '2:11 3:413', 'fleet_size_max_movement': '2:10 3:377', 'routes__type__dist': '2:1 3:190', 'calendar_dates__exception_type__dist': '1:2 2:160', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': ':1', 'stops__location_type__dist': '0:5811', 'latest_feed_start_date': '2022-05-06', 'earliest_feed_end_date': '2022-06-25'}
# ------------------------------ getting statistics for Edmonton-AB
# {'n_agencies': 3, 'n_routes': 220, 'n_stops': 6222, 'n_stop_times': 2098576, 'n_trips': 64072, 'n_calendar': 1034, 'n_shapes': 223379, 'n_calendar_dates': 8606, 'n_days': 511071, 'n_stop_distances': 289850, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 2038, 'agencies': 'Edmonton Transit Service_St. Albert Transit_Strathcona County Transit', 'lat_min': 53.302688, 'lat_10': 53.44951399999999, 'lat_median': 53.541404, 'lat_90': 53.6254421, 'lat_max': 53.704407, 'lon_min': -113.934884, 'lon_10': -113.6272479, 'lon_median': -113.504221, 'lon_90': -113.3894945, 'lon_max': -113.218139, 'height_km': 44.71915452198306, 'width_km': 79.7876884286252, 'start_time_ut': 1652421600, 'end_time_ut': 1656842400, 'start_date': '2022-05-13', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-19', 'max_activity_hour': 7, 'fleet_size_route_based': '0:16 3:618', 'fleet_size_max_movement': '0:16 3:529', 'routes__type__dist': '0:2 3:218', 'calendar_dates__exception_type__dist': '1:8606', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '0:29 1:851 2:1140 3:18', 'agencies__lang__dist': 'EN:3', 'stops__location_type__dist': '0:6074 1:18 2:83 3:47', 'latest_feed_start_date': '2022-05-13', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Mississauga-ON
# {'n_agencies': 1, 'n_routes': 69, 'n_stops': 4192, 'n_stop_times': 1124225, 'n_trips': 27058, 'n_calendar': 18, 'n_shapes': 113273, 'n_calendar_dates': 190, 'n_days': 481996, 'n_stop_distances': 209316, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'MiWay', 'lat_min': 43.469292, 'lat_10': 43.538900899999994, 'lat_median': 43.5958425, 'lat_90': 43.6897721, 'lat_max': 43.838069, 'lon_min': -79.797795, 'lon_10': -79.7439986, 'lon_median': -79.65584000000001, 'lon_90': -79.5908933, 'lon_max': -79.512874, 'height_km': 41.05206785627042, 'width_km': 31.71726063630998, 'start_time_ut': 1648180800, 'end_time_ut': 1656316800, 'start_date': '2022-03-25', 'end_date': '2022-06-26', 'max_activity_date': '2022-03-25', 'max_activity_hour': 18, 'fleet_size_route_based': '3:258', 'fleet_size_max_movement': '3:248', 'routes__type__dist': '3:69', 'calendar_dates__exception_type__dist': '1:190', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:3261 1:931', 'latest_feed_start_date': '2022-03-25', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Winnipeg-MN
# {'n_agencies': 1, 'n_routes': 84, 'n_stops': 5155, 'n_stop_times': 668713, 'n_trips': 11826, 'n_calendar': 3, 'n_shapes': 108630, 'n_calendar_dates': 2, 'n_days': 315749, 'n_stop_distances': 314292, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Winnipeg Transit', 'lat_min': 49.763940715545736, 'lat_10': 49.816419536441984, 'lat_median': 49.886553784851365, 'lat_90': 49.94082112616242, 'lat_max': 49.969473678569834, 'lon_min': -97.32299682965768, 'lon_10': -97.22700468301599, 'lon_median': -97.14964403597519, 'lon_90': -97.06404926622446, 'lon_max': -96.96269333563113, 'height_km': 22.879824785075275, 'width_km': 40.10880148607317, 'start_time_ut': 1650171600, 'end_time_ut': 1655629200, 'start_date': '2022-04-17', 'end_date': '2022-06-18', 'max_activity_date': '2022-04-18', 'max_activity_hour': 7, 'fleet_size_route_based': '3:386', 'fleet_size_max_movement': '3:357', 'routes__type__dist': '3:84', 'calendar_dates__exception_type__dist': '1:1 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:5155', 'latest_feed_start_date': '2022-04-17', 'earliest_feed_end_date': '2022-06-18'}
# ------------------------------ getting statistics for Vancouver-BC
# {'n_agencies': 1, 'n_routes': 241, 'n_stops': 8777, 'n_stop_times': 1761315, 'n_trips': 60140, 'n_calendar': 37, 'n_shapes': 157556, 'n_calendar_dates': 560, 'n_days': 1560227, 'n_stop_distances': 340786, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 5281, 'agencies': 'TransLink', 'lat_min': 49.004383, 'lat_10': 49.1030736, 'lat_median': 49.22474, 'lat_90': 49.3121544, 'lat_max': 49.474111, 'lon_min': -123.423063, 'lon_10': -123.1474544, 'lon_median': -122.967318, 'lon_90': -122.6720698, 'lon_max': -122.30486, 'height_km': 52.2898817713432, 'width_km': 124.47778856351023, 'start_time_ut': 1650265200, 'end_time_ut': 1656327600, 'start_date': '2022-04-18', 'end_date': '2022-06-26', 'max_activity_date': '2022-04-22', 'max_activity_hour': 17, 'fleet_size_route_based': '1:75 3:989 4:3', 'fleet_size_max_movement': '1:73 2:2 3:1018 4:3', 'routes__type__dist': '1:3 2:1 3:236 4:1', 'calendar_dates__exception_type__dist': '1:559 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '0:3284 2:1997', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:8718 1:59', 'latest_feed_start_date': '2022-04-18', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Brampton-ON
# {'n_agencies': 1, 'n_routes': 66, 'n_stops': 2890, 'n_stop_times': 355825, 'n_trips': 8928, 'n_calendar': 3, 'n_shapes': 47705, 'n_calendar_dates': 0, 'n_days': 110592, 'n_stop_distances': 117930, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Brampton Transit', 'lat_min': 43.591827, 'lat_10': 43.657627399999996, 'lat_median': 43.712847, 'lat_90': 43.7696947, 'lat_max': 43.819111, 'lon_min': -79.861496, 'lon_10': -79.81734619999999, 'lon_median': -79.744316, 'lon_90': -79.6682166, 'lon_max': -79.527649, 'height_km': 25.301139145458098, 'width_km': 37.16367804286264, 'start_time_ut': 1653883200, 'end_time_ut': 1656316800, 'start_date': '2022-05-30', 'end_date': '2022-06-26', 'max_activity_date': '2022-05-30', 'max_activity_hour': 7, 'fleet_size_route_based': '3:264', 'fleet_size_max_movement': '3:253', 'routes__type__dist': '3:66', 'calendar_dates__exception_type__dist': '', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:2868 1:22', 'latest_feed_start_date': '2022-05-30', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Hamilton-ON
# {'n_agencies': 1, 'n_routes': 38, 'n_stops': 2418, 'n_stop_times': 798667, 'n_trips': 16921, 'n_calendar': 34, 'n_shapes': 71217, 'n_calendar_dates': 183, 'n_days': 180391, 'n_stop_distances': 127546, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'Hamilton Street Railway', 'lat_min': 43.156343, 'lat_10': 43.1996063, 'lat_median': 43.234283, 'lat_90': 43.2617463, 'lat_max': 43.326073, 'lon_min': -80.031354, 'lon_10': -79.9426133, 'lon_median': -79.85736800000001, 'lon_90': -79.77718150000001, 'lon_max': -79.692514, 'height_km': 18.894257172342463, 'width_km': 37.71949626039176, 'start_time_ut': 1651377600, 'end_time_ut': 1656230400, 'start_date': '2022-05-01', 'end_date': '2022-06-25', 'max_activity_date': '2022-05-02', 'max_activity_hour': 15, 'fleet_size_route_based': '3:190', 'fleet_size_max_movement': '3:173', 'routes__type__dist': '3:38', 'calendar_dates__exception_type__dist': '1:182 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:2415 1:3', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-06-25'}
# ------------------------------ getting statistics for Quebec-City-QC
# {'n_agencies': 1, 'n_routes': 322, 'n_stops': 4652, 'n_stop_times': 2170236, 'n_trips': 44427, 'n_calendar': 22, 'n_shapes': 275234, 'n_calendar_dates': 225, 'n_days': 568526, 'n_stop_distances': 270564, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 758, 'agencies': 'Réseau de transport de la Capitale (RTC)', 'lat_min': 46.733235, 'lat_10': 46.7595714, 'lat_median': 46.833155000000005, 'lat_90': 46.8924966, 'lat_max': 46.943394, 'lon_min': -71.520955, 'lon_10': -71.38219099999999, 'lon_median': -71.2973375, 'lon_90': -71.20578619999999, 'lon_max': -71.113523, 'height_km': 23.39479286562328, 'width_km': 45.35512277288504, 'start_time_ut': 1561608000, 'end_time_ut': 1575104400, 'start_date': '2019-06-27', 'end_date': '2019-11-29', 'max_activity_date': '2019-08-23', 'max_activity_hour': 7, 'fleet_size_route_based': '3:420', 'fleet_size_max_movement': '3:353', 'routes__type__dist': '3:322', 'calendar_dates__exception_type__dist': '1:225', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:758', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': '0:4652', 'latest_feed_start_date': '2019-06-27', 'earliest_feed_end_date': '2019-11-29'}
# ------------------------------ getting statistics for Surrey-BC
# {'n_agencies': 1, 'n_routes': 241, 'n_stops': 8777, 'n_stop_times': 1761315, 'n_trips': 60140, 'n_calendar': 37, 'n_shapes': 157556, 'n_calendar_dates': 560, 'n_days': 1560227, 'n_stop_distances': 340786, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 5281, 'agencies': 'TransLink', 'lat_min': 49.004383, 'lat_10': 49.1030736, 'lat_median': 49.22474, 'lat_90': 49.3121544, 'lat_max': 49.474111, 'lon_min': -123.423063, 'lon_10': -123.1474544, 'lon_median': -122.967318, 'lon_90': -122.6720698, 'lon_max': -122.30486, 'height_km': 52.2898817713432, 'width_km': 124.47778856351023, 'start_time_ut': 1650265200, 'end_time_ut': 1656327600, 'start_date': '2022-04-18', 'end_date': '2022-06-26', 'max_activity_date': '2022-04-22', 'max_activity_hour': 17, 'fleet_size_route_based': '1:75 3:989 4:3', 'fleet_size_max_movement': '1:73 2:2 3:1018 4:3', 'routes__type__dist': '1:3 2:1 3:236 4:1', 'calendar_dates__exception_type__dist': '1:559 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '0:3284 2:1997', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:8718 1:59', 'latest_feed_start_date': '2022-04-18', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Laval-QC
# {'n_agencies': 1, 'n_routes': 95, 'n_stops': 2861, 'n_stop_times': 355678, 'n_trips': 5837, 'n_calendar': 3, 'n_shapes': 39774, 'n_calendar_dates': 91, 'n_days': 418917, 'n_stop_distances': 140478, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'Societe de transport de Laval', 'lat_min': 45.504517, 'lat_10': 45.533586, 'lat_median': 45.578839, 'lat_90': 45.657824, 'lat_max': 45.699292, 'lon_min': -73.87801, 'lon_10': -73.81594, 'lon_median': -73.73826, 'lon_90': -73.64264, 'lon_max': -73.53437, 'height_km': 21.682253819259852, 'width_km': 38.25382981620139, 'start_time_ut': 1648267200, 'end_time_ut': 1656144000, 'start_date': '2022-03-26', 'end_date': '2022-06-24', 'max_activity_date': '2022-03-28', 'max_activity_hour': 7, 'fleet_size_route_based': '', 'fleet_size_max_movement': '3:330', 'routes__type__dist': '3:95', 'calendar_dates__exception_type__dist': '1:91', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': '0:2861', 'latest_feed_start_date': '2022-03-26', 'earliest_feed_end_date': '2022-06-24'}
# ------------------------------ getting statistics for Halifax-NS
# {'n_agencies': 1, 'n_routes': 80, 'n_stops': 2421, 'n_stop_times': 320861, 'n_trips': 9213, 'n_calendar': 7, 'n_shapes': 63437, 'n_calendar_dates': 23, 'n_days': 353426, 'n_stop_distances': 97916, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Halifax Transit', 'lat_min': 44.565098, 'lat_10': 44.629688, 'lat_median': 44.672127, 'lat_90': 44.754823, 'lat_max': 44.886253, 'lon_min': -63.858243, 'lon_10': -63.688342, 'lon_median': -63.597466, 'lon_90': -63.491351, 'lon_max': -63.28321, 'height_km': 35.750811065714274, 'width_km': 64.01238074932901, 'start_time_ut': 1653274800, 'end_time_ut': 1661756400, 'start_date': '2022-05-23', 'end_date': '2022-08-28', 'max_activity_date': '2022-05-24', 'max_activity_hour': 17, 'fleet_size_route_based': '3:188 4:4', 'fleet_size_max_movement': '3:210 4:4', 'routes__type__dist': '3:78 4:2', 'calendar_dates__exception_type__dist': '1:20 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:2410 1:11', 'latest_feed_start_date': '2022-05-23', 'earliest_feed_end_date': '2022-08-28'}
# ------------------------------ getting statistics for Vaughan-ON
# {'n_agencies': 1, 'n_routes': 143, 'n_stops': 4581, 'n_stop_times': 441324, 'n_trips': 11071, 'n_calendar': 12, 'n_shapes': 117294, 'n_calendar_dates': 153, 'n_days': 202880, 'n_stop_distances': 145912, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'York Region Transit', 'lat_min': 43.720413, 'lat_10': 43.799275, 'lat_median': 43.869092, 'lat_90': 44.053179, 'lat_max': 44.32131, 'lon_min': -79.659289, 'lon_10': -79.543736, 'lon_median': -79.441694, 'lon_90': -79.264689, 'lon_max': -79.212178, 'height_km': 66.89154805920529, 'width_km': 49.772168848072084, 'start_time_ut': 1651377600, 'end_time_ut': 1656835200, 'start_date': '2022-05-01', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-02', 'max_activity_hour': 7, 'fleet_size_route_based': '3:276', 'fleet_size_max_movement': '3:246', 'routes__type__dist': '3:143', 'calendar_dates__exception_type__dist': '1:151 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:4565 1:16', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Gatineau-QC
# {'n_agencies': 1, 'n_routes': 105, 'n_stops': 1978, 'n_stop_times': 568816, 'n_trips': 13890, 'n_calendar': 9, 'n_shapes': 104271, 'n_calendar_dates': 57, 'n_days': 117131, 'n_stop_distances': 78996, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'STO', 'lat_min': 45.381261, 'lat_10': 45.405504300000004, 'lat_median': 45.464576, 'lat_90': 45.5185994, 'lat_max': 45.592886, 'lon_min': -75.890201, 'lon_10': -75.8342126, 'lon_median': -75.72962100000001, 'lon_90': -75.5635671, 'lon_max': -75.390856, 'height_km': 23.55798723912629, 'width_km': 55.58683113016777, 'start_time_ut': 1652673600, 'end_time_ut': 1657612800, 'start_date': '2022-05-16', 'end_date': '2022-07-11', 'max_activity_date': '2022-05-16', 'max_activity_hour': 7, 'fleet_size_route_based': '3:226', 'fleet_size_max_movement': '3:177', 'routes__type__dist': '3:105', 'calendar_dates__exception_type__dist': '1:57', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': '0:1978', 'latest_feed_start_date': '2022-05-16', 'earliest_feed_end_date': '2022-07-11'}
# ------------------------------ getting statistics for Saskatoon-SK
# {'n_agencies': 1, 'n_routes': 107, 'n_stops': 1471, 'n_stop_times': 271069, 'n_trips': 11534, 'n_calendar': 6, 'n_shapes': 195289, 'n_calendar_dates': 4, 'n_days': 163474, 'n_stop_distances': 66270, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 19, 'agencies': 'Saskatoon Transit', 'lat_min': 52.078661, 'lat_10': 52.10017, 'lat_median': 52.128418, 'lat_90': 52.163796, 'lat_max': 52.202189, 'lon_min': -106.760746, 'lon_10': -106.721298, 'lon_median': -106.647538, 'lon_90': -106.582977, 'lon_max': -106.532035, 'height_km': 13.75107405871153, 'width_km': 25.45999205882085, 'start_time_ut': 1650780000, 'end_time_ut': 1656842400, 'start_date': '2022-04-24', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-30', 'max_activity_hour': 8, 'fleet_size_route_based': '3:150', 'fleet_size_max_movement': '3:76', 'routes__type__dist': '3:107', 'calendar_dates__exception_type__dist': '1:2 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:19', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1465 1:6', 'latest_feed_start_date': '2022-04-24', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Windsor-ON
# {'n_agencies': 1, 'n_routes': 17, 'n_stops': 1244, 'n_stop_times': 72871, 'n_trips': 1486, 'n_calendar': 3, 'n_shapes': 13803, 'n_calendar_dates': 2, 'n_days': 85750, 'n_stop_distances': 44828, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Transit Windsor', 'lat_min': 42.042087, 'lat_10': 42.247453846, 'lat_median': 42.302750605, 'lat_90': 42.324790703999994, 'lat_max': 42.34243354, 'lon_min': -83.103199, 'lon_10': -83.0644835, 'lon_median': -83.01005799999999, 'lon_90': -82.93634599100001, 'lon_max': -82.606767, 'height_km': 33.43442389432153, 'width_km': 55.26255745348624, 'start_time_ut': 1650772800, 'end_time_ut': 1660550400, 'start_date': '2022-04-24', 'end_date': '2022-08-14', 'max_activity_date': '2022-04-25', 'max_activity_hour': 15, 'fleet_size_route_based': '3:52', 'fleet_size_max_movement': '3:52', 'routes__type__dist': '3:17', 'calendar_dates__exception_type__dist': '1:1 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1244', 'latest_feed_start_date': '2022-04-24', 'earliest_feed_end_date': '2022-08-14'}
# ------------------------------ getting statistics for Regina-SK
# {'n_agencies': 1, 'n_routes': 42, 'n_stops': 1383, 'n_stop_times': 238408, 'n_trips': 3856, 'n_calendar': 6, 'n_shapes': 45128, 'n_calendar_dates': 10, 'n_days': 210021, 'n_stop_distances': 64880, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 319, 'agencies': 'The City of Regina', 'lat_min': 50.40078, 'lat_10': 50.415532, 'lat_median': 50.45467, 'lat_90': 50.48777, 'lat_max': 50.50887, 'lon_min': -104.7079, 'lon_10': -104.666444, 'lon_median': -104.618191, 'lon_90': -104.547338, 'lon_max': -104.503773, 'height_km': 12.032523759845411, 'width_km': 22.723313697158524, 'start_time_ut': 1641103200, 'end_time_ut': 1661680800, 'start_date': '2022-01-02', 'end_date': '2022-08-27', 'max_activity_date': '2022-01-03', 'max_activity_hour': 16, 'fleet_size_route_based': '3:68', 'fleet_size_max_movement': '3:81', 'routes__type__dist': '3:42', 'calendar_dates__exception_type__dist': '1:5 2:5', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '1:319', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1383', 'latest_feed_start_date': '2022-01-02', 'earliest_feed_end_date': '2022-08-27'}
# ------------------------------ getting statistics for Richmond-Hill-ON
# {'n_agencies': 1, 'n_routes': 143, 'n_stops': 4581, 'n_stop_times': 441324, 'n_trips': 11071, 'n_calendar': 12, 'n_shapes': 117294, 'n_calendar_dates': 153, 'n_days': 202880, 'n_stop_distances': 145912, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'York Region Transit', 'lat_min': 43.720413, 'lat_10': 43.799275, 'lat_median': 43.869092, 'lat_90': 44.053179, 'lat_max': 44.32131, 'lon_min': -79.659289, 'lon_10': -79.543736, 'lon_median': -79.441694, 'lon_90': -79.264689, 'lon_max': -79.212178, 'height_km': 66.89154805920529, 'width_km': 49.772168848072084, 'start_time_ut': 1651377600, 'end_time_ut': 1656835200, 'start_date': '2022-05-01', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-02', 'max_activity_hour': 7, 'fleet_size_route_based': '3:276', 'fleet_size_max_movement': '3:246', 'routes__type__dist': '3:143', 'calendar_dates__exception_type__dist': '1:151 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:4565 1:16', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Oakville-ON
# {'n_agencies': 1, 'n_routes': 33, 'n_stops': 1129, 'n_stop_times': 74102, 'n_trips': 2103, 'n_calendar': 3, 'n_shapes': 75516, 'n_calendar_dates': 4, 'n_days': 58417, 'n_stop_distances': 39950, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 5, 'agencies': 'Oakville Transit', 'lat_min': 43.372358, 'lat_10': 43.40338, 'lat_median': 43.4501, 'lat_90': 43.4945152, 'lat_max': 43.543996, 'lon_min': -79.829729, 'lon_10': -79.753982, 'lon_median': -79.7101, 'lon_90': -79.6704016, 'lon_max': -79.632124, 'height_km': 19.106654760776056, 'width_km': 21.99728797820436, 'start_time_ut': 1651377600, 'end_time_ut': 1656835200, 'start_date': '2022-05-01', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-02', 'max_activity_hour': 7, 'fleet_size_route_based': '3:60', 'fleet_size_max_movement': '3:56', 'routes__type__dist': '3:33', 'calendar_dates__exception_type__dist': '1:2 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '1:5', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:1129', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Burlington-ON
# {'n_agencies': 1, 'n_routes': 16, 'n_stops': 793, 'n_stop_times': 95424, 'n_trips': 2088, 'n_calendar': 4, 'n_shapes': 21175, 'n_calendar_dates': 1, 'n_days': 36258, 'n_stop_distances': 23834, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'Burlington Transit', 'lat_min': 43.256679, 'lat_10': 43.3180234, 'lat_median': 43.361472, 'lat_90': 43.393285399999996, 'lat_max': 43.411717, 'lon_min': -79.892603, 'lon_10': -79.84422860000001, 'lon_median': -79.800524, 'lon_90': -79.760039, 'lon_max': -79.725184, 'height_km': 17.258751213608065, 'width_km': 18.636997829118542, 'start_time_ut': 1647144000, 'end_time_ut': 1651392000, 'start_date': '2022-03-13', 'end_date': '2022-04-30', 'max_activity_date': '2022-03-14', 'max_activity_hour': 8, 'fleet_size_route_based': '3:38', 'fleet_size_max_movement': '3:33', 'routes__type__dist': '3:16', 'calendar_dates__exception_type__dist': '2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:793', 'latest_feed_start_date': '2022-03-13', 'earliest_feed_end_date': '2022-04-30'}
# ------------------------------ getting statistics for Greater-Sudbury-ON
# {'n_agencies': 1, 'n_routes': 44, 'n_stops': 1073, 'n_stop_times': 163413, 'n_trips': 4630, 'n_calendar': 4630, 'n_shapes': 16157, 'n_calendar_dates': 112984, 'n_days': 112984, 'n_stop_distances': 35254, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Greater Sudbury Transit', 'lat_min': 46.3981059752405, 'lat_10': 46.45676001906398, 'lat_median': 46.4979289937765, 'lat_90': 46.63092160038656, 'lat_max': 46.7159690335393, 'lon_min': -81.2044530082495, 'lon_10': -81.10943483188754, 'lon_median': -80.9937970060856, 'lon_90': -80.92421877756725, 'lon_max': -80.8472879603506, 'height_km': 35.38435379181559, 'width_km': 39.75943126126102, 'start_time_ut': 1651377600, 'end_time_ut': 1661587200, 'start_date': '2022-05-01', 'end_date': '2022-08-26', 'max_activity_date': '2022-05-02', 'max_activity_hour': 16, 'fleet_size_route_based': '', 'fleet_size_max_movement': '3:34', 'routes__type__dist': '3:44', 'calendar_dates__exception_type__dist': '1:112984', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:1073', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-08-26'}
# ------------------------------ getting statistics for Levis-QC
# {'n_agencies': 1, 'n_routes': 81, 'n_stops': 1718, 'n_stop_times': 79134, 'n_trips': 1565, 'n_calendar': 11, 'n_shapes': 42954, 'n_calendar_dates': 600, 'n_days': 85797, 'n_stop_distances': 69178, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 7, 'agencies': 'Société de transport de Lévis', 'lat_min': 46.552296, 'lat_10': 46.666066099999995, 'lat_median': 46.7408085, 'lat_90': 46.817518400000004, 'lat_max': 46.828171, 'lon_min': -71.409636, 'lon_10': -71.3239798, 'lon_median': -71.2194485, 'lon_90': -71.1446479, 'lon_max': -71.064983, 'height_km': 30.710264522594258, 'width_km': 38.366596460375014, 'start_time_ut': 1629691200, 'end_time_ut': 1639990800, 'start_date': '2021-08-23', 'end_date': '2021-12-19', 'max_activity_date': '2021-09-01', 'max_activity_hour': 7, 'fleet_size_route_based': '3:89', 'fleet_size_max_movement': '3:76', 'routes__type__dist': '3:81', 'calendar_dates__exception_type__dist': '1:600', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:7', 'agencies__lang__dist': 'FR:1', 'stops__location_type__dist': 'None:1718', 'latest_feed_start_date': '2021-08-23', 'earliest_feed_end_date': '2021-12-19'}
# ------------------------------ getting statistics for Barrie-ON
# {'n_agencies': 1, 'n_routes': 20, 'n_stops': 652, 'n_stop_times': 60566, 'n_trips': 1518, 'n_calendar': 4, 'n_shapes': 3706, 'n_calendar_dates': 56, 'n_days': 32046, 'n_stop_distances': 19640, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'Barrie Transit', 'lat_min': 44.3218044, 'lat_10': 44.338548370999995, 'lat_median': 44.37222176, 'lat_90': 44.408084718000005, 'lat_max': 44.42020676, 'lon_min': -79.74063237, 'lon_10': -79.72087957400001, 'lon_median': -79.6935003494108, 'lon_90': -79.652808324, 'lon_max': -79.61089569, 'height_km': 10.954100608056555, 'width_km': 14.442221154809156, 'start_time_ut': 1650772800, 'end_time_ut': 1655625600, 'start_date': '2022-04-24', 'end_date': '2022-06-18', 'max_activity_date': '2022-04-25', 'max_activity_hour': 10, 'fleet_size_route_based': '3:14', 'fleet_size_max_movement': '3:30', 'routes__type__dist': '3:20', 'calendar_dates__exception_type__dist': '1:56', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:652', 'latest_feed_start_date': '2022-04-24', 'earliest_feed_end_date': '2022-06-18'}
# ------------------------------ getting statistics for Abbotsford-BC
# {'n_agencies': 1, 'n_routes': 22, 'n_stops': 623, 'n_stop_times': 48493, 'n_trips': 1711, 'n_calendar': 3, 'n_shapes': 25289, 'n_calendar_dates': 0, 'n_days': 76632, 'n_stop_distances': 19152, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'BC Transit - Central Fraser Valley Transit System', 'lat_min': 49.004222, 'lat_10': 49.038277400000005, 'lat_median': 49.0534, 'lat_90': 49.139897600000005, 'lat_max': 49.158304, 'lon_min': -122.470676, 'lon_10': -122.3600582, 'lon_median': -122.302378, 'lon_90': -122.25019900000001, 'lon_max': -122.214539, 'height_km': 17.152329780409456, 'width_km': 28.5130404133162, 'start_time_ut': 1647327600, 'end_time_ut': 1656673200, 'start_date': '2022-03-15', 'end_date': '2022-06-30', 'max_activity_date': '2022-03-15', 'max_activity_hour': 16, 'fleet_size_route_based': '3:29', 'fleet_size_max_movement': '3:29', 'routes__type__dist': '3:22', 'calendar_dates__exception_type__dist': '', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:623', 'latest_feed_start_date': '2022-03-15', 'earliest_feed_end_date': '2022-06-30'}
# ------------------------------ getting statistics for Coquitlam-ON
# {'n_agencies': 1, 'n_routes': 241, 'n_stops': 8777, 'n_stop_times': 1761315, 'n_trips': 60140, 'n_calendar': 37, 'n_shapes': 157556, 'n_calendar_dates': 560, 'n_days': 1560227, 'n_stop_distances': 340786, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 5281, 'agencies': 'TransLink', 'lat_min': 49.004383, 'lat_10': 49.1030736, 'lat_median': 49.22474, 'lat_90': 49.3121544, 'lat_max': 49.474111, 'lon_min': -123.423063, 'lon_10': -123.1474544, 'lon_median': -122.967318, 'lon_90': -122.6720698, 'lon_max': -122.30486, 'height_km': 52.2898817713432, 'width_km': 124.47778856351023, 'start_time_ut': 1650265200, 'end_time_ut': 1656327600, 'start_date': '2022-04-18', 'end_date': '2022-06-26', 'max_activity_date': '2022-04-22', 'max_activity_hour': 17, 'fleet_size_route_based': '1:75 3:989 4:3', 'fleet_size_max_movement': '1:73 2:2 3:1018 4:3', 'routes__type__dist': '1:3 2:1 3:236 4:1', 'calendar_dates__exception_type__dist': '1:559 2:1', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '0:3284 2:1997', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:8718 1:59', 'latest_feed_start_date': '2022-04-18', 'earliest_feed_end_date': '2022-06-26'}
# ------------------------------ getting statistics for Guelph-ON
# {'n_agencies': 1, 'n_routes': 22, 'n_stops': 553, 'n_stop_times': 77976, 'n_trips': 2623, 'n_calendar': 5, 'n_shapes': 15381, 'n_calendar_dates': 6, 'n_days': 123343, 'n_stop_distances': 15162, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Guelph Transit', 'lat_min': 43.482707, 'lat_10': 43.5061612, 'lat_median': 43.538884, 'lat_90': 43.5655804, 'lat_max': 43.580844, 'lon_min': -80.322631, 'lon_10': -80.2906632, 'lon_median': -80.245397, 'lon_90': -80.2075166, 'lon_max': -80.175535, 'height_km': 10.924560867979627, 'width_km': 16.3746518177279, 'start_time_ut': 1651377600, 'end_time_ut': 1662278400, 'start_date': '2022-05-01', 'end_date': '2022-09-03', 'max_activity_date': '2022-05-02', 'max_activity_hour': 15, 'fleet_size_route_based': '3:10', 'fleet_size_max_movement': '3:43', 'routes__type__dist': '3:22', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:553', 'latest_feed_start_date': '2022-05-01', 'earliest_feed_end_date': '2022-09-03'}
# ------------------------------ getting statistics for Ajax-ON
# {'n_agencies': 1, 'n_routes': 27, 'n_stops': 1739, 'n_stop_times': 194108, 'n_trips': 4375, 'n_calendar': 4, 'n_shapes': 64165, 'n_calendar_dates': 4, 'n_days': 127095, 'n_stop_distances': 40582, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Durham Region Transit', 'lat_min': 43.774936, 'lat_10': 43.8287816, 'lat_median': 43.887869, 'lat_90': 43.949188472, 'lat_max': 44.112316, 'lon_min': -79.252857, 'lon_10': -79.0935392, 'lon_median': -78.939683, 'lon_90': -78.8324488, 'lon_max': -78.673813, 'height_km': 37.55696980383498, 'width_km': 64.45888322690145, 'start_time_ut': 1649044800, 'end_time_ut': 1655712000, 'start_date': '2022-04-04', 'end_date': '2022-06-19', 'max_activity_date': '2022-04-04', 'max_activity_hour': 17, 'fleet_size_route_based': '3:84', 'fleet_size_max_movement': '3:81', 'routes__type__dist': '3:27', 'calendar_dates__exception_type__dist': '1:2 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1739', 'latest_feed_start_date': '2022-04-04', 'earliest_feed_end_date': '2022-06-19'}
# ------------------------------ getting statistics for Terrebone-QC
# {'n_agencies': 1, 'n_routes': 42, 'n_stops': 1077, 'n_stop_times': 119521, 'n_trips': 2963, 'n_calendar': 8, 'n_shapes': 104079, 'n_calendar_dates': 6, 'n_days': 64596, 'n_stop_distances': 33704, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Terrebonne-Mascouche', 'lat_min': 45.5542, 'lat_10': 45.6876424, 'lat_median': 45.719969, 'lat_90': 45.7683362, 'lat_max': 45.80231, 'lon_min': -73.842682, 'lon_10': -73.737417, 'lon_median': -73.656044, 'lon_90': -73.590644, 'lon_max': -73.498242, 'height_km': 27.61947886071877, 'width_km': 38.34288540883421, 'start_time_ut': 1652673600, 'end_time_ut': 1661155200, 'start_date': '2022-05-16', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-16', 'max_activity_hour': 7, 'fleet_size_route_based': '3:71', 'fleet_size_max_movement': '3:57', 'routes__type__dist': '3:42', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:1077', 'latest_feed_start_date': '2022-05-16', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Milton-ON
# {'n_agencies': 1, 'n_routes': 12, 'n_stops': 328, 'n_stop_times': 26755, 'n_trips': 636, 'n_calendar': 636, 'n_shapes': 3558, 'n_calendar_dates': 19166, 'n_days': 19166, 'n_stop_distances': 11174, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 6, 'agencies': 'Milton Transit', 'lat_min': 43.48015, 'lat_10': 43.488794999999996, 'lat_median': 43.511025000000004, 'lat_90': 43.529446, 'lat_max': 43.54222, 'lon_min': -79.89257, 'lon_10': -79.88287399999999, 'lon_median': -79.86257499999999, 'lon_90': -79.839586, 'lon_max': -79.82503, 'height_km': 6.909600793538326, 'width_km': 7.518518408178605, 'start_time_ut': 1648008000, 'end_time_ut': 1656662400, 'start_date': '2022-03-23', 'end_date': '2022-06-30', 'max_activity_date': '2022-03-23', 'max_activity_hour': 7, 'fleet_size_route_based': '', 'fleet_size_max_movement': '3:12', 'routes__type__dist': '3:12', 'calendar_dates__exception_type__dist': '1:19166', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '1:6', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:328', 'latest_feed_start_date': '2022-03-23', 'earliest_feed_end_date': '2022-06-30'}
# ------------------------------ getting statistics for Thunder-Bay-ON
# {'n_agencies': 1, 'n_routes': 18, 'n_stops': 793, 'n_stop_times': 166366, 'n_trips': 4797, 'n_calendar': 4877, 'n_shapes': 12174, 'n_calendar_dates': 88145, 'n_days': 83905, 'n_stop_distances': 31046, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 13, 'agencies': 'Thunder Bay Transit', 'lat_min': 48.34626, 'lat_10': 48.367444000000006, 'lat_median': 48.40285, 'lat_90': 48.453044, 'lat_max': 48.47868, 'lon_min': -89.38849, 'lon_10': -89.29185600000001, 'lon_median': -89.25398, 'lon_90': -89.21586400000001, 'lon_max': -89.1819, 'height_km': 14.740926970844862, 'width_km': 22.997493602983013, 'start_time_ut': 1652500800, 'end_time_ut': 1661673600, 'start_date': '2022-05-14', 'end_date': '2022-08-27', 'max_activity_date': '2022-05-16', 'max_activity_hour': 8, 'fleet_size_route_based': '', 'fleet_size_max_movement': '3:30', 'routes__type__dist': '3:18', 'calendar_dates__exception_type__dist': '1:88145', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '1:13', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:793', 'latest_feed_start_date': '2022-05-14', 'earliest_feed_end_date': '2022-08-27'}
# ------------------------------ getting statistics for Red-Deer-AB
# {'n_agencies': 1, 'n_routes': 40, 'n_stops': 606, 'n_stop_times': 43332, 'n_trips': 1496, 'n_calendar': 3, 'n_shapes': 62203, 'n_calendar_dates': 6, 'n_days': 179322, 'n_stop_distances': 20596, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Red Deer Transit', 'lat_min': 52.204934, 'lat_10': 52.240984, 'lat_median': 52.266592, 'lat_90': 52.3023615, 'lat_max': 52.315697, 'lon_min': -113.859632, 'lon_10': -113.837992, 'lon_median': -113.807155, 'lon_90': -113.75837150000001, 'lon_max': -113.746221, 'height_km': 12.330080758735207, 'width_km': 12.624854770355867, 'start_time_ut': 1630216800, 'end_time_ut': 1656842400, 'start_date': '2021-08-29', 'end_date': '2022-07-02', 'max_activity_date': '2021-08-30', 'max_activity_hour': 15, 'fleet_size_route_based': '3:25', 'fleet_size_max_movement': '3:35', 'routes__type__dist': '3:40', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:606', 'latest_feed_start_date': '2021-08-29', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Strathcona-County-AB
# {'n_agencies': 3, 'n_routes': 220, 'n_stops': 6222, 'n_stop_times': 2098576, 'n_trips': 64072, 'n_calendar': 1034, 'n_shapes': 223379, 'n_calendar_dates': 8606, 'n_days': 511071, 'n_stop_distances': 289850, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 2038, 'agencies': 'Edmonton Transit Service_St. Albert Transit_Strathcona County Transit', 'lat_min': 53.302688, 'lat_10': 53.44951399999999, 'lat_median': 53.541404, 'lat_90': 53.6254421, 'lat_max': 53.704407, 'lon_min': -113.934884, 'lon_10': -113.6272479, 'lon_median': -113.504221, 'lon_90': -113.3894945, 'lon_max': -113.218139, 'height_km': 44.71915452198306, 'width_km': 79.7876884286252, 'start_time_ut': 1652421600, 'end_time_ut': 1656842400, 'start_date': '2022-05-13', 'end_date': '2022-07-02', 'max_activity_date': '2022-05-19', 'max_activity_hour': 7, 'fleet_size_route_based': '0:16 3:618', 'fleet_size_max_movement': '0:16 3:529', 'routes__type__dist': '0:2 3:218', 'calendar_dates__exception_type__dist': '1:8606', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '0:29 1:851 2:1140 3:18', 'agencies__lang__dist': 'EN:3', 'stops__location_type__dist': '0:6074 1:18 2:83 3:47', 'latest_feed_start_date': '2022-05-13', 'earliest_feed_end_date': '2022-07-02'}
# ------------------------------ getting statistics for Brantford-ON
# {'n_agencies': 1, 'n_routes': 46, 'n_stops': 1062, 'n_stop_times': 1176078, 'n_trips': 62553, 'n_calendar': 45, 'n_shapes': 261979, 'n_calendar_dates': 45, 'n_days': 62553, 'n_stop_distances': 5870, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 4, 'agencies': 'GO Transit', 'lat_min': 42.981586, 'lat_10': 43.4778244, 'lat_median': 43.829881650000004, 'lat_90': 44.10114289, 'lat_max': 44.4297562, 'lon_min': -81.244272, 'lon_10': -80.02845839999999, 'lon_median': -79.555752, 'lon_90': -78.94783557, 'lon_max': -78.2870331, 'height_km': 161.20956924599312, 'width_km': 329.19832850205967, 'start_time_ut': 1652241600, 'end_time_ut': 1656144000, 'start_date': '2022-05-11', 'end_date': '2022-06-24', 'max_activity_date': '2022-05-11', 'max_activity_hour': 7, 'fleet_size_route_based': '2:27 3:118', 'fleet_size_max_movement': '2:25 3:115', 'routes__type__dist': '2:7 3:39', 'calendar_dates__exception_type__dist': '1:45', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:4', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1062', 'latest_feed_start_date': '2022-05-11', 'earliest_feed_end_date': '2022-06-24'}
# ------------------------------ getting statistics for Saint-Jean-sur-Richelieu-QC
# {'n_agencies': 1, 'n_routes': 23, 'n_stops': 390, 'n_stop_times': 21244, 'n_trips': 1102, 'n_calendar': 6, 'n_shapes': 26159, 'n_calendar_dates': 6, 'n_days': 34506, 'n_stop_distances': 9306, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Chambly-Richelieu-Carignan', 'lat_min': 45.297081, 'lat_10': 45.4313583, 'lat_median': 45.444151500000004, 'lat_90': 45.4792716, 'lat_max': 45.541135, 'lon_min': -73.566033, 'lon_10': -73.36289719999999, 'lon_median': -73.29287099999999, 'lon_90': -73.18580279999999, 'lon_max': -73.143402, 'height_km': 27.16796700606142, 'width_km': 47.04706771345308, 'start_time_ut': 1650945600, 'end_time_ut': 1661155200, 'start_date': '2022-04-26', 'end_date': '2022-08-21', 'max_activity_date': '2022-04-26', 'max_activity_hour': 6, 'fleet_size_route_based': '3:36', 'fleet_size_max_movement': '3:24', 'routes__type__dist': '3:23', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:390', 'latest_feed_start_date': '2022-04-26', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Lethbridge-AB
# {'n_agencies': 1, 'n_routes': 13, 'n_stops': 446, 'n_stop_times': 43918, 'n_trips': 1558, 'n_calendar': 5, 'n_shapes': 6297, 'n_calendar_dates': 235, 'n_days': 130616, 'n_stop_distances': 14665, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 16, 'agencies': 'Lethbridge Transit', 'lat_min': 49.6515019030274, 'lat_10': 49.6675857703439, 'lat_median': 49.69293398815, 'lat_90': 49.727136848994306, 'lat_max': 49.7383759759889, 'lon_min': -112.913215781046, 'lon_10': -112.886454709557, 'lon_median': -112.8240765824365, 'lon_90': -112.7988591223275, 'lon_max': -112.781255112961, 'height_km': 9.670777565211859, 'width_km': 14.689794375962395, 'start_time_ut': 1652248800, 'end_time_ut': 1672570800, 'start_date': '2022-05-11', 'end_date': '2022-12-31', 'max_activity_date': '2022-05-11', 'max_activity_hour': 13, 'fleet_size_route_based': '3:24', 'fleet_size_max_movement': '3:19', 'routes__type__dist': '3:13', 'calendar_dates__exception_type__dist': '1:235', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '1:16', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:446', 'latest_feed_start_date': '2022-05-11', 'earliest_feed_end_date': '2022-12-31'}
# ------------------------------ getting statistics for Pickering-ON
# {'n_agencies': 1, 'n_routes': 46, 'n_stops': 1062, 'n_stop_times': 1176078, 'n_trips': 62553, 'n_calendar': 45, 'n_shapes': 261979, 'n_calendar_dates': 45, 'n_days': 62553, 'n_stop_distances': 5870, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 4, 'agencies': 'GO Transit', 'lat_min': 42.981586, 'lat_10': 43.4778244, 'lat_median': 43.829881650000004, 'lat_90': 44.10114289, 'lat_max': 44.4297562, 'lon_min': -81.244272, 'lon_10': -80.02845839999999, 'lon_median': -79.555752, 'lon_90': -78.94783557, 'lon_max': -78.2870331, 'height_km': 161.20956924599312, 'width_km': 329.19832850205967, 'start_time_ut': 1652241600, 'end_time_ut': 1656144000, 'start_date': '2022-05-11', 'end_date': '2022-06-24', 'max_activity_date': '2022-05-11', 'max_activity_hour': 7, 'fleet_size_route_based': '2:27 3:118', 'fleet_size_max_movement': '2:25 3:115', 'routes__type__dist': '2:7 3:39', 'calendar_dates__exception_type__dist': '1:45', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:4', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1062', 'latest_feed_start_date': '2022-05-11', 'earliest_feed_end_date': '2022-06-24'}
# ------------------------------ getting statistics for Nanaimo-BC
# {'n_agencies': 1, 'n_routes': 20, 'n_stops': 822, 'n_stop_times': 145350, 'n_trips': 4145, 'n_calendar': 7, 'n_shapes': 23815, 'n_calendar_dates': 6, 'n_days': 71784, 'n_stop_distances': 19340, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'BC Transit - RDN Transit System', 'lat_min': 48.774918, 'lat_10': 49.1399271, 'lat_median': 49.20855, 'lat_90': 49.346083799999995, 'lat_max': 49.464455, 'lon_min': -124.72594, 'lon_10': -124.40329840000001, 'lon_median': -124.001439, 'lon_90': -123.9316502, 'lon_max': -123.701411, 'height_km': 76.75890772312164, 'width_km': 114.0500465829419, 'start_time_ut': 1648364400, 'end_time_ut': 1659006000, 'start_date': '2022-03-27', 'end_date': '2022-07-27', 'max_activity_date': '2022-03-29', 'max_activity_hour': 8, 'fleet_size_route_based': '3:41', 'fleet_size_max_movement': '3:41', 'routes__type__dist': '3:20', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:817 1:5', 'latest_feed_start_date': '2022-03-27', 'earliest_feed_end_date': '2022-07-27'}
# ...
# ------------------------------ getting statistics for North-Cowichan-BC
# {'n_agencies': 1, 'n_routes': 16, 'n_stops': 599, 'n_stop_times': 16432, 'n_trips': 562, 'n_calendar': 5, 'n_shapes': 12706, 'n_calendar_dates': 36, 'n_days': 32832, 'n_stop_distances': 8448, 'n_frequencies': 0, 'n_feed_info': 0, 'n_transfers': 0, 'agencies': 'BCTransit', 'lat_min': 48.41583, 'lat_10': 48.652288, 'lat_median': 48.7832, 'lat_90': 48.927966, 'lat_max': 48.99831, 'lon_min': -124.21862, 'lon_10': -123.82975, 'lon_median': -123.69006, 'lon_90': -123.561328, 'lon_max': -123.36445, 'height_km': 64.84137699726563, 'width_km': 95.08576945089006, 'start_time_ut': 1652598000, 'end_time_ut': 1672574400, 'start_date': '2022-05-15', 'end_date': '2022-12-31', 'max_activity_date': '2022-05-20', 'max_activity_hour': 15, 'fleet_size_route_based': '3:9', 'fleet_size_max_movement': '3:9', 'routes__type__dist': '3:16', 'calendar_dates__exception_type__dist': '1:34 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': 'None:599', 'latest_feed_start_date': '2022-05-15', 'earliest_feed_end_date': '2022-12-31'}
# ------------------------------ getting statistics for Grimsby-ON
# {'n_agencies': 1, 'n_routes': 46, 'n_stops': 1062, 'n_stop_times': 1176078, 'n_trips': 62553, 'n_calendar': 45, 'n_shapes': 261979, 'n_calendar_dates': 45, 'n_days': 62553, 'n_stop_distances': 5870, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 4, 'agencies': 'GO Transit', 'lat_min': 42.981586, 'lat_10': 43.4778244, 'lat_median': 43.829881650000004, 'lat_90': 44.10114289, 'lat_max': 44.4297562, 'lon_min': -81.244272, 'lon_10': -80.02845839999999, 'lon_median': -79.555752, 'lon_90': -78.94783557, 'lon_max': -78.2870331, 'height_km': 161.20956924599312, 'width_km': 329.19832850205967, 'start_time_ut': 1652241600, 'end_time_ut': 1656144000, 'start_date': '2022-05-11', 'end_date': '2022-06-24', 'max_activity_date': '2022-05-11', 'max_activity_hour': 7, 'fleet_size_route_based': '2:27 3:118', 'fleet_size_max_movement': '2:25 3:115', 'routes__type__dist': '2:7 3:39', 'calendar_dates__exception_type__dist': '1:45', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '2:4', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1062', 'latest_feed_start_date': '2022-05-11', 'earliest_feed_end_date': '2022-06-24'}
# ------------------------------ getting statistics for Boisbriand-QC
# {'n_agencies': 1, 'n_routes': 88, 'n_stops': 2231, 'n_stop_times': 313207, 'n_trips': 7418, 'n_calendar': 12, 'n_shapes': 133814, 'n_calendar_dates': 4, 'n_days': 123156, 'n_stop_distances': 103040, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Laurentides', 'lat_min': 45.460471, 'lat_10': 45.538682, 'lat_median': 45.649137, 'lat_90': 45.778794, 'lat_max': 45.813779, 'lon_min': -74.206726, 'lon_10': -74.005545, 'lon_median': -73.861215, 'lon_90': -73.784591, 'lon_max': -73.56419, 'height_km': 39.330066653189725, 'width_km': 71.52678033634758, 'start_time_ut': 1652673600, 'end_time_ut': 1661155200, 'start_date': '2022-05-16', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-20', 'max_activity_hour': 17, 'fleet_size_route_based': '3:70', 'fleet_size_max_movement': '3:101', 'routes__type__dist': '3:88', 'calendar_dates__exception_type__dist': '1:1 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:2231', 'latest_feed_start_date': '2022-05-16', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Sainte-Therese-QC
# {'n_agencies': 1, 'n_routes': 88, 'n_stops': 2231, 'n_stop_times': 313207, 'n_trips': 7418, 'n_calendar': 12, 'n_shapes': 133814, 'n_calendar_dates': 4, 'n_days': 123156, 'n_stop_distances': 103040, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Laurentides', 'lat_min': 45.460471, 'lat_10': 45.538682, 'lat_median': 45.649137, 'lat_90': 45.778794, 'lat_max': 45.813779, 'lon_min': -74.206726, 'lon_10': -74.005545, 'lon_median': -73.861215, 'lon_90': -73.784591, 'lon_max': -73.56419, 'height_km': 39.330066653189725, 'width_km': 71.52678033634758, 'start_time_ut': 1652673600, 'end_time_ut': 1661155200, 'start_date': '2022-05-16', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-20', 'max_activity_hour': 17, 'fleet_size_route_based': '3:70', 'fleet_size_max_movement': '3:101', 'routes__type__dist': '3:88', 'calendar_dates__exception_type__dist': '1:1 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:2231', 'latest_feed_start_date': '2022-05-16', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Sept-Iies-QC
# {'n_agencies': 1, 'n_routes': 37, 'n_stops': 980, 'n_stop_times': 48787, 'n_trips': 1873, 'n_calendar': 9, 'n_shapes': 60772, 'n_calendar_dates': 66, 'n_days': 35581, 'n_stop_distances': 48760, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': "exo-La Presqu'île", 'lat_min': 45.350844, 'lat_10': 45.3721012, 'lat_median': 45.389727, 'lat_90': 45.43016790000001, 'lat_max': 45.513436, 'lon_min': -74.315165, 'lon_10': -74.1484682, 'lon_median': -74.0239885, 'lon_90': -73.9264734, 'lon_max': -73.682942, 'height_km': 18.09965864705955, 'width_km': 70.37874242779537, 'start_time_ut': 1652414400, 'end_time_ut': 1661155200, 'start_date': '2022-05-13', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-30', 'max_activity_hour': 6, 'fleet_size_route_based': '3:53', 'fleet_size_max_movement': '3:28', 'routes__type__dist': '3:37', 'calendar_dates__exception_type__dist': '1:3 2:63', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:980', 'latest_feed_start_date': '2022-05-13', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Beloeil-QC
# {'n_agencies': 1, 'n_routes': 34, 'n_stops': 691, 'n_stop_times': 67759, 'n_trips': 1894, 'n_calendar': 9, 'n_shapes': 62667, 'n_calendar_dates': 66, 'n_days': 36748, 'n_stop_distances': 19168, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Vallée du Richelieu', 'lat_min': 45.496375, 'lat_10': 45.523614, 'lat_median': 45.569848, 'lat_90': 45.637052, 'lat_max': 45.652233, 'lon_min': -73.564192, 'lon_10': -73.295975, 'lon_median': -73.187526, 'lon_90': -72.94797, 'lon_max': -72.88893, 'height_km': 17.350033196058263, 'width_km': 75.1698219920479, 'start_time_ut': 1651809600, 'end_time_ut': 1661155200, 'start_date': '2022-05-06', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-06', 'max_activity_hour': 7, 'fleet_size_route_based': '3:30', 'fleet_size_max_movement': '3:38', 'routes__type__dist': '3:34', 'calendar_dates__exception_type__dist': '1:3 2:63', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:691', 'latest_feed_start_date': '2022-05-06', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for LAssomption-QC
# {'n_agencies': 1, 'n_routes': 14, 'n_stops': 825, 'n_stop_times': 87050, 'n_trips': 1554, 'n_calendar': 6, 'n_shapes': 74980, 'n_calendar_dates': 6, 'n_days': 33959, 'n_stop_distances': 28244, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': "exo-L'Assomption", 'lat_min': 45.589483, 'lat_10': 45.7197896, 'lat_median': 45.761636, 'lat_90': 45.847055600000004, 'lat_max': 45.901438, 'lon_min': -73.539828, 'lon_10': -73.4969864, 'lon_median': -73.460396, 'lon_90': -73.413931, 'lon_max': -73.277404, 'height_km': 34.726671750415385, 'width_km': 29.21290605193355, 'start_time_ut': 1652155200, 'end_time_ut': 1661155200, 'start_date': '2022-05-10', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-10', 'max_activity_hour': 17, 'fleet_size_route_based': '3:26', 'fleet_size_max_movement': '3:32', 'routes__type__dist': '3:14', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:825', 'latest_feed_start_date': '2022-05-10', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Scugog-ON
# {'n_agencies': 1, 'n_routes': 27, 'n_stops': 1739, 'n_stop_times': 194108, 'n_trips': 4375, 'n_calendar': 4, 'n_shapes': 64165, 'n_calendar_dates': 4, 'n_days': 127095, 'n_stop_distances': 40582, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'Durham Region Transit', 'lat_min': 43.774936, 'lat_10': 43.8287816, 'lat_median': 43.887869, 'lat_90': 43.949188472, 'lat_max': 44.112316, 'lon_min': -79.252857, 'lon_10': -79.0935392, 'lon_median': -78.939683, 'lon_90': -78.8324488, 'lon_max': -78.673813, 'height_km': 37.55696980383498, 'width_km': 64.45888322690145, 'start_time_ut': 1649044800, 'end_time_ut': 1655712000, 'start_date': '2022-04-04', 'end_date': '2022-06-19', 'max_activity_date': '2022-04-04', 'max_activity_hour': 17, 'fleet_size_route_based': '3:84', 'fleet_size_max_movement': '3:81', 'routes__type__dist': '3:27', 'calendar_dates__exception_type__dist': '1:2 2:2', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:1739', 'latest_feed_start_date': '2022-04-04', 'earliest_feed_end_date': '2022-06-19'}
# ------------------------------ getting statistics for Varennes-QC
# {'n_agencies': 1, 'n_routes': 15, 'n_stops': 349, 'n_stop_times': 28777, 'n_trips': 784, 'n_calendar': 6, 'n_shapes': 66177, 'n_calendar_dates': 6, 'n_days': 19563, 'n_stop_distances': 7066, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Sorel-Varennes', 'lat_min': 45.524297, 'lat_10': 45.6255608, 'lat_median': 45.674273, 'lat_90': 45.932895599999995, 'lat_max': 46.037695, 'lon_min': -73.540802, 'lon_10': -73.4350268, 'lon_median': -73.328157, 'lon_90': -73.20664160000001, 'lon_max': -73.088162, 'height_km': 57.15120393428531, 'width_km': 50.38765431266762, 'start_time_ut': 1652414400, 'end_time_ut': 1661155200, 'start_date': '2022-05-13', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-13', 'max_activity_hour': 17, 'fleet_size_route_based': '3:13', 'fleet_size_max_movement': '3:22', 'routes__type__dist': '3:15', 'calendar_dates__exception_type__dist': '1:3 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:349', 'latest_feed_start_date': '2022-05-13', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Saint-Lin-Laurentides-QC
# {'n_agencies': 1, 'n_routes': 88, 'n_stops': 2231, 'n_stop_times': 313207, 'n_trips': 7418, 'n_calendar': 12, 'n_shapes': 133814, 'n_calendar_dates': 4, 'n_days': 123156, 'n_stop_distances': 103040, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'exo-Laurentides', 'lat_min': 45.460471, 'lat_10': 45.538682, 'lat_median': 45.649137, 'lat_90': 45.778794, 'lat_max': 45.813779, 'lon_min': -74.206726, 'lon_10': -74.005545, 'lon_median': -73.861215, 'lon_90': -73.784591, 'lon_max': -73.56419, 'height_km': 39.330066653189725, 'width_km': 71.52678033634758, 'start_time_ut': 1652673600, 'end_time_ut': 1661155200, 'start_date': '2022-05-16', 'end_date': '2022-08-21', 'max_activity_date': '2022-05-20', 'max_activity_hour': 17, 'fleet_size_route_based': '3:70', 'fleet_size_max_movement': '3:101', 'routes__type__dist': '3:88', 'calendar_dates__exception_type__dist': '1:1 2:3', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'fr:1', 'stops__location_type__dist': 'None:2231', 'latest_feed_start_date': '2022-05-16', 'earliest_feed_end_date': '2022-08-21'}
# ------------------------------ getting statistics for Fort-St-John-BC
# {'n_agencies': 1, 'n_routes': 5, 'n_stops': 82, 'n_stop_times': 6976, 'n_trips': 227, 'n_calendar': 4, 'n_shapes': 1018, 'n_calendar_dates': 58, 'n_days': 22889, 'n_stop_distances': 1462, 'n_frequencies': 0, 'n_feed_info': 1, 'n_transfers': 0, 'agencies': 'BC Transit - Fort St John Transit System', 'lat_min': 56.231758, 'lat_10': 56.235621200000004, 'lat_median': 56.24565, 'lat_90': 56.2609868, 'lat_max': 56.26674, 'lon_min': -120.873862, 'lon_10': -120.85769660000001, 'lon_median': -120.8408145, 'lon_90': -120.81610400000001, 'lon_max': -120.803019, 'height_km': 3.89417842693023, 'width_km': 7.886206686267482, 'start_time_ut': 1637650800, 'end_time_ut': 1672570800, 'start_date': '2021-11-23', 'end_date': '2022-12-31', 'max_activity_date': '2022-07-01', 'max_activity_hour': 10, 'fleet_size_route_based': '', 'fleet_size_max_movement': '3:6', 'routes__type__dist': '3:5', 'calendar_dates__exception_type__dist': '2:58', 'frequencies__exact_times__dist': '', 'transfers__transfer_type__dist': '', 'agencies__lang__dist': 'en:1', 'stops__location_type__dist': '0:82', 'latest_feed_start_date': '2021-11-23', 'earliest_feed_end_date': '2022-12-31'}
#    index           Id  GeographicCode GeographicName CSDType  \
# 0      0   Toronto-ON         3520005        Toronto    City
# 1      1  Montreal-QC         2466023       Montréal   Ville
# 2      2   Calgary-AB         4806016        Calgary    City
# 3      3    Ottawa-ON         3506008         Ottawa    City
# 4      4  Edmonton-AB         4811061       Edmonton    City
#
#   ProvinceTerritory  GeographicCodeProvinceTerritory  \
# 0           Ontario                               35
# 1            Quebec                               24
# 2           Alberta                               48
# 3           Ontario                               35
# 4           Alberta                               48
#
#    GeographicCodeCensusDivision  Population2016  Population2011  ...  \
# 0                          3520         2731571         2615060  ...
# 1                          2466         1704694         1649519  ...
# 2                          4806         1239220         1096833  ...
# 3                          3506          934243          883391  ...
# 4                          4811          932546          812201  ...
#
#    NationalPopulationRank2016  ProvincialTerritorialPopulationRank2016  \
# 0                           1                                        1
# 1                           2                                        1
# 2                           3                                        1
# 3                           4                                        2
# 4                           5                                        2
#
#    n_routes  n_stops  n_trips   n_days  height_km   width_km    ut_start  \
# 0       188     9464   123210  1439969  35.388021  58.642774  1602388800
# 1       219     9034   203003  2938442  33.223079  52.946110  1641186000
# 2       275     6193    23433   412124  36.671089  49.868349  1652076000
# 3       191     5811    29548   387026  43.365176  77.934442  1651809600
# 4       220     6222    64072   511071  44.719155  79.787688  1652421600
#
#        ut_end
# 0  1606035600
# 1  1655107200
# 2  1656324000
# 3  1656230400
# 4  1656842400
#
# [5 rows x 29 columns]

# %%
# Calculate the stops by GTFS coverage density (stops/km^2) and the trip temporal density (trips/ut_window)
df_all['stop_spatial_density'] = df_all.apply(lambda row: row.n_stops / (row.height_km * row.width_km), axis=1)
df_all['trip_temporal_density'] = df_all.apply(lambda row: row.n_trips / (row.ut_end - row.ut_start), axis=1)
df_all.tail()
# Out:
#     index                        Id  GeographicCode         GeographicName  \
# 77    185            LAssomption-QC         2460028           L'Assomption
# 78    191                 Scugog-ON         3518020                 Scugog
# 79    197               Varennes-QC         2459020               Varennes
# 80    203  Saint-Lin-Laurentides-QC         2463048  Saint-Lin-Laurentides
# 81    211           Fort-St-John-BC         5955034          Fort St. John
#
#      CSDType ProvinceTerritory  GeographicCodeProvinceTerritory  \
# 77     Ville            Quebec                               24
# 78  Township           Ontario                               35
# 79     Ville            Quebec                               24
# 80     Ville            Quebec                               24
# 81      City  British Columbia                               59
#
#     GeographicCodeCensusDivision  Population2016  Population2011  ...  \
# 77                          2460           22429           20065  ...
# 78                          3518           21617           21569  ...
# 79                          2459           21257           20994  ...
# 80                          2463           20786           17463  ...
# 81                          5955           20155           18609  ...
#
#     n_routes  n_stops  n_trips  n_days  height_km   width_km    ut_start  \
# 77        14      825     1554   33959  34.726672  29.212906  1652155200
# 78        27     1739     4375  127095  37.556970  64.458883  1649044800
# 79        15      349      784   19563  57.151204  50.387654  1652414400
# 80        88     2231     7418  123156  39.330067  71.526780  1652673600
# 81         5       82      227   22889   3.894178   7.886207  1637650800
#
#         ut_end  stop_spatial_density  trip_temporal_density
# 77  1661155200              0.813235               0.000173
# 78  1655712000              0.718334               0.000656
# 79  1661155200              0.121193               0.000090
# 80  1661155200              0.793060               0.000875
# 81  1672570800              2.670114               0.000007
#
# [5 rows x 31 columns]

# %%
df_all.columns
# Out:
# Index(['index', 'Id', 'GeographicCode', 'GeographicName', 'CSDType',
#        'ProvinceTerritory', 'GeographicCodeProvinceTerritory',
#        'GeographicCodeCensusDivision', 'Population2016', 'Population2011',
#        'PopulationPercentChange', 'TotalPrivateDwellings2016',
#        'TotalPrivateDwellings2011', 'TotalPrivateDwellingsPercentChange',
#        'PrivateDwellingsOccupiedByUsualResidents2016',
#        'PrivateDwellingsOccupiedByUsualResidents2011',
#        'PrivateDwellingsOccupiedByUsualResidentsPercentChange',
#        'LandAreaInSquareKilometres2016',
#        'PopulationDensityPerSquareKilometre2016', 'NationalPopulationRank2016',
#        'ProvincialTerritorialPopulationRank2016', 'n_routes', 'n_stops',
#        'n_trips', 'n_days', 'height_km', 'width_km', 'ut_start', 'ut_end',
#        'stop_spatial_density', 'trip_temporal_density'],
#       dtype='object')

# %%
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False

def r2(x, y):
    return '{0:.3g}'.format(stats.pearsonr(x, y)[0] ** 2)

def create_corr_plot(x, y, save_path):
    ax = sns.regplot(x=df_all[x], y=df_all[y], robust=True)
    ax.set_title(f"Correlation Plot; R2 = {r2(df_all[x], df_all[y])}")
    plt.savefig(save_path)
    plt.show()
    plt.clf()
    
fig_path = "../figures/"
pairs = [
    ("Population2016", "n_stops"),
    ("Population2011", "n_stops"),
    ("Population2016", "n_trips"),
    ("TotalPrivateDwellings2016", "n_stops"),
    ("LandAreaInSquareKilometres2016", "n_stops"),
    ("Population2016", "trip_temporal_density"),
    ("Population2016", "stop_spatial_density"),
    ("stop_spatial_density", 'trip_temporal_density')
]
    
for pair in pairs: create_corr_plot(pair[0], pair[1], os.path.join(fig_path, f"{pair[0]}_{pair[1]}.svg"))

# %%
# Prepare all of our variables of interests for a large-scale correlation table

corr_table_y = ['Population2016', 'Population2011',
       'PopulationPercentChange', 'TotalPrivateDwellings2016',
       'TotalPrivateDwellings2011', 'TotalPrivateDwellingsPercentChange',
       'PrivateDwellingsOccupiedByUsualResidents2016',
       'PrivateDwellingsOccupiedByUsualResidents2011',
       'PrivateDwellingsOccupiedByUsualResidentsPercentChange',
       'LandAreaInSquareKilometres2016',
       'PopulationDensityPerSquareKilometre2016', 'NationalPopulationRank2016',
       'ProvincialTerritorialPopulationRank2016']

corr_table_x = ['n_routes', 'n_stops',
       'n_trips', 'n_days', 'height_km', 'width_km', 'ut_start', 'ut_end',
       'stop_spatial_density', 'trip_temporal_density']

# Compute the pearson and spearman correlation for all paired values
csv_output = [['Census-Value'] + ['Correlation'] + corr_table_x]
for census_val in corr_table_y:
    pearson_row  = [census_val] + ['Pearson']
    spearman_row = [census_val] + ['Spearman']
    for gtfs_val in corr_table_x:
        #print(f'Getting correlations for {census_val} and {gtfs_val}')
        pearson  = stats.pearsonr(df_all[census_val], df_all[gtfs_val])[0]
        spearman = stats.spearmanr(df_all[census_val], df_all[gtfs_val])[0]
    
        pearson_row.append(pearson)
        spearman_row.append(spearman)
    csv_output.append(pearson_row)
    csv_output.append(spearman_row)

out = []
for row in csv_output: out.append(','.join(map(str, row)))

# Save to file to colour and clean up manually
open('../tables/complete_correlation_table.csv', 'w').write('\n'.join([row for row in out]))
# Out:
# Getting correlations for Population2016 and n_routes
# Getting correlations for Population2016 and n_stops
# Getting correlations for Population2016 and n_trips
# Getting correlations for Population2016 and n_days
# Getting correlations for Population2016 and height_km
# Getting correlations for Population2016 and width_km
# Getting correlations for Population2016 and ut_start
# Getting correlations for Population2016 and ut_end
# Getting correlations for Population2016 and stop_spatial_density
# Getting correlations for Population2016 and trip_temporal_density
# Getting correlations for Population2011 and n_routes
# Getting correlations for Population2011 and n_stops
# Getting correlations for Population2011 and n_trips
# Getting correlations for Population2011 and n_days
# Getting correlations for Population2011 and height_km
# Getting correlations for Population2011 and width_km
# Getting correlations for Population2011 and ut_start
# Getting correlations for Population2011 and ut_end
# Getting correlations for Population2011 and stop_spatial_density
# Getting correlations for Population2011 and trip_temporal_density
# Getting correlations for PopulationPercentChange and n_routes
# Getting correlations for PopulationPercentChange and n_stops
# Getting correlations for PopulationPercentChange and n_trips
# Getting correlations for PopulationPercentChange and n_days
# Getting correlations for PopulationPercentChange and height_km
# Getting correlations for PopulationPercentChange and width_km
# Getting correlations for PopulationPercentChange and ut_start
# Getting correlations for PopulationPercentChange and ut_end
# Getting correlations for PopulationPercentChange and stop_spatial_density
# Getting correlations for PopulationPercentChange and trip_temporal_density
# Getting correlations for TotalPrivateDwellings2016 and n_routes
# Getting correlations for TotalPrivateDwellings2016 and n_stops
# Getting correlations for TotalPrivateDwellings2016 and n_trips
# Getting correlations for TotalPrivateDwellings2016 and n_days
# Getting correlations for TotalPrivateDwellings2016 and height_km
# Getting correlations for TotalPrivateDwellings2016 and width_km
# Getting correlations for TotalPrivateDwellings2016 and ut_start
# Getting correlations for TotalPrivateDwellings2016 and ut_end
# Getting correlations for TotalPrivateDwellings2016 and stop_spatial_density
# Getting correlations for TotalPrivateDwellings2016 and trip_temporal_density
# Getting correlations for TotalPrivateDwellings2011 and n_routes
# Getting correlations for TotalPrivateDwellings2011 and n_stops
# Getting correlations for TotalPrivateDwellings2011 and n_trips
# Getting correlations for TotalPrivateDwellings2011 and n_days
# Getting correlations for TotalPrivateDwellings2011 and height_km
# Getting correlations for TotalPrivateDwellings2011 and width_km
# Getting correlations for TotalPrivateDwellings2011 and ut_start
# Getting correlations for TotalPrivateDwellings2011 and ut_end
# Getting correlations for TotalPrivateDwellings2011 and stop_spatial_density
# Getting correlations for TotalPrivateDwellings2011 and trip_temporal_density
# Getting correlations for TotalPrivateDwellingsPercentChange and n_routes
# Getting correlations for TotalPrivateDwellingsPercentChange and n_stops
# Getting correlations for TotalPrivateDwellingsPercentChange and n_trips
# Getting correlations for TotalPrivateDwellingsPercentChange and n_days
# Getting correlations for TotalPrivateDwellingsPercentChange and height_km
# Getting correlations for TotalPrivateDwellingsPercentChange and width_km
# Getting correlations for TotalPrivateDwellingsPercentChange and ut_start
# Getting correlations for TotalPrivateDwellingsPercentChange and ut_end
# Getting correlations for TotalPrivateDwellingsPercentChange and stop_spatial_density
# Getting correlations for TotalPrivateDwellingsPercentChange and trip_temporal_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and n_routes
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and n_stops
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and n_trips
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and n_days
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and height_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and width_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and ut_start
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and ut_end
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and stop_spatial_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2016 and trip_temporal_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and n_routes
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and n_stops
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and n_trips
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and n_days
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and height_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and width_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and ut_start
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and ut_end
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and stop_spatial_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidents2011 and trip_temporal_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and n_routes
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and n_stops
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and n_trips
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and n_days
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and height_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and width_km
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and ut_start
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and ut_end
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and stop_spatial_density
# Getting correlations for PrivateDwellingsOccupiedByUsualResidentsPercentChange and trip_temporal_density
# Getting correlations for LandAreaInSquareKilometres2016 and n_routes
# Getting correlations for LandAreaInSquareKilometres2016 and n_stops
# Getting correlations for LandAreaInSquareKilometres2016 and n_trips
# Getting correlations for LandAreaInSquareKilometres2016 and n_days
# Getting correlations for LandAreaInSquareKilometres2016 and height_km
# Getting correlations for LandAreaInSquareKilometres2016 and width_km
# Getting correlations for LandAreaInSquareKilometres2016 and ut_start
# Getting correlations for LandAreaInSquareKilometres2016 and ut_end
# Getting correlations for LandAreaInSquareKilometres2016 and stop_spatial_density
# Getting correlations for LandAreaInSquareKilometres2016 and trip_temporal_density
# Getting correlations for PopulationDensityPerSquareKilometre2016 and n_routes
# Getting correlations for PopulationDensityPerSquareKilometre2016 and n_stops
# Getting correlations for PopulationDensityPerSquareKilometre2016 and n_trips
# Getting correlations for PopulationDensityPerSquareKilometre2016 and n_days
# Getting correlations for PopulationDensityPerSquareKilometre2016 and height_km
# Getting correlations for PopulationDensityPerSquareKilometre2016 and width_km
# Getting correlations for PopulationDensityPerSquareKilometre2016 and ut_start
# Getting correlations for PopulationDensityPerSquareKilometre2016 and ut_end
# Getting correlations for PopulationDensityPerSquareKilometre2016 and stop_spatial_density
# Getting correlations for PopulationDensityPerSquareKilometre2016 and trip_temporal_density
# Getting correlations for NationalPopulationRank2016 and n_routes
# Getting correlations for NationalPopulationRank2016 and n_stops
# Getting correlations for NationalPopulationRank2016 and n_trips
# Getting correlations for NationalPopulationRank2016 and n_days
# Getting correlations for NationalPopulationRank2016 and height_km
# Getting correlations for NationalPopulationRank2016 and width_km
# Getting correlations for NationalPopulationRank2016 and ut_start
# Getting correlations for NationalPopulationRank2016 and ut_end
# Getting correlations for NationalPopulationRank2016 and stop_spatial_density
# Getting correlations for NationalPopulationRank2016 and trip_temporal_density
# Getting correlations for ProvincialTerritorialPopulationRank2016 and n_routes
# Getting correlations for ProvincialTerritorialPopulationRank2016 and n_stops
# Getting correlations for ProvincialTerritorialPopulationRank2016 and n_trips
# Getting correlations for ProvincialTerritorialPopulationRank2016 and n_days
# Getting correlations for ProvincialTerritorialPopulationRank2016 and height_km
# Getting correlations for ProvincialTerritorialPopulationRank2016 and width_km
# Getting correlations for ProvincialTerritorialPopulationRank2016 and ut_start
# Getting correlations for ProvincialTerritorialPopulationRank2016 and ut_end
# Getting correlations for ProvincialTerritorialPopulationRank2016 and stop_spatial_density
# Getting correlations for ProvincialTerritorialPopulationRank2016 and trip_temporal_density
# 6433

# %% [markdown]
# ## Prepare an Over-/Under-Representation Figure
#
# To illustrate the biases of our collected GTFS data, we with to express the percent difference between the number of CSDs with population > 20K in a given province/territory versus the number of CSDs with population > 20k AND has validated GTFS data in a given province/territory. Those with a percent change close to 0% are unbiased whereas those with a large positive percentage change are over-represented and those with a large negative percent change are under-represented.

# %%
df_all.groupby(['ProvinceTerritory']).size().sort_values(ascending=False).plot(kind = "bar", sort_columns=True,rot=45)

# %%
df_raw.groupby(['ProvinceTerritory']).size().sort_values(ascending=False).plot(kind = "bar", sort_columns=True,rot=80)

# %%
df_raw.groupby(['ProvinceTerritory']).size().sort_values(ascending=False)
# Out:
# ProvinceTerritory
# Ontario                      83
# Quebec                       57
# British Columbia             33
# Alberta                      20
# Nova Scotia                   5
# New Brunswick                 4
# Newfoundland and Labrador     4
# Saskatchewan                  4
# Manitoba                      2
# Prince Edward Island          1
# Yukon                         1
# dtype: int64

# %%
total_CSD_pop_over20k = df_raw.shape[0]
total_CSD_pop_over20k_wGTFS = df_clean.shape[0]
print(f"Total number of CSD with Pop. over 20K: {total_CSD_pop_over20k}\nTotal number of CSD with Pop. over 20K with GTFS: {total_CSD_pop_over20k_wGTFS}")

# Used to normalize the number of CSDs over 20k
def div_by_total_CSD20k(x):
    return x/total_CSD_pop_over20k

# Used to normalize the number of CSDs over 20k with GTFS data
def div_by_total_CSD20k_wGTFS(x):
    return x/total_CSD_pop_over20k_wGTFS

raw_counts = df_raw.groupby(['ProvinceTerritory']).size().sort_values(ascending=False)
raw_norm_counts = raw_counts.apply(div_by_total_CSD20k)
raw_norm_counts = raw_norm_counts.rename("raw")

clean_counts = df_all.groupby(['ProvinceTerritory']).size().sort_values(ascending=False)
clean_norm_counts = clean_counts.apply(div_by_total_CSD20k_wGTFS)
clean_norm_counts = clean_norm_counts.rename("clean")
# Out:
# Total number of CSD with Pop. over 20K: 214
# Total number of CSD with Pop. over 20K with GTFS: 82

# %%
raw_norm_counts
# Out:
# ProvinceTerritory
# Ontario                      0.387850
# Quebec                       0.266355
# British Columbia             0.154206
# Alberta                      0.093458
# Nova Scotia                  0.023364
# New Brunswick                0.018692
# Newfoundland and Labrador    0.018692
# Saskatchewan                 0.018692
# Manitoba                     0.009346
# Prince Edward Island         0.004673
# Yukon                        0.004673
# Name: raw, dtype: float64

# %%
clean_norm_counts
# Out:
# ProvinceTerritory
# Ontario             0.292683
# Quebec              0.280488
# British Columbia    0.219512
# Alberta             0.146341
# Saskatchewan        0.036585
# Manitoba            0.012195
# Nova Scotia         0.012195
# Name: clean, dtype: float64

# %%
df_merge = pd.merge(raw_norm_counts, clean_norm_counts, right_index = True, left_index = True)

# %%
df_merge['diff_percentage'] = df_merge.apply(lambda row: (row.clean - row.raw) * 100, axis=1)
df_merge
# Out:
#                         raw     clean  diff_percentage
# ProvinceTerritory
# Ontario            0.387850  0.292683        -9.516754
# Quebec             0.266355  0.280488         1.413266
# British Columbia   0.154206  0.219512         6.530659
# Alberta            0.093458  0.146341         5.288352
# Nova Scotia        0.023364  0.012195        -1.116936
# Saskatchewan       0.018692  0.036585         1.789378
# Manitoba           0.009346  0.012195         0.284933

# %%
import matplotlib.ticker as ticker
hfont = {'fontname':'Helvetica'}

for i in range(df_merge.shape[0]):
    df_merge['color'] = ['lightblue' if float(x) < 0 else 'pink' for x in df_merge['diff_percentage']]
  
# Sort values from lowest to highest
df_merge.sort_values('diff_percentage', inplace=True)
  
# Resets initial index in Dataframe to None
#df_merge.reset_index(inplace=True)
  
# Draw plot
plt.figure(figsize=(9, 3), dpi=300)
  
# Plotting the horizontal lines
plt.hlines(y=df_merge.index, xmin=0, xmax=df_merge.diff_percentage, color=df_merge.color, alpha=0.8, linewidth=21)
  
# Decorations
# Setting the labels of x-axis and y-axis
plt.gca().set(ylabel='Province/Territory', xlabel='Under-/Over-Representation')

# Title of Bar Chart
plt.title('GTFS Data Availability Represenataion', fontdict={'size': 10}, **hfont)
plt.yticks(range(0,len(df_merge.index)), df_merge.sort_values(by='diff_percentage', ascending=True)['ProvinceTerritory'], **hfont)

# TODO: Figure out adding values to these plots
for idx, val in enumerate(df_merge.sort_values(by='diff_percentage', ascending=True)['diff_percentage']):
    print(val)
    ann = '{0:.3g}%'.format(val)
    if val > 0: ann = '+' + ann
    plt.annotate(ann, xy=(val/2, idx),xytext=(val/6, idx-0.15), size=8, **hfont)

plt.savefig('../figures/GTFS-data-avilability-representation.svg')
# Out:
# -9.516754046045135
# -1.1169364030088897
# 0.28493275586961486
# 1.4132664691132946
# 1.7893777068611807
# 5.28835194894005
# 6.530658764531571

# %%
df_merge.sort_values(by='diff_percentage', ascending=True)
# Out:
#    level_0  index ProvinceTerritory       raw     clean  diff_percentage  \
# 0        0      0           Ontario  0.387850  0.292683        -9.516754
# 1        1      1       Nova Scotia  0.023364  0.012195        -1.116936
# 2        2      2          Manitoba  0.009346  0.012195         0.284933
# 3        3      3            Quebec  0.266355  0.280488         1.413266
# 4        4      4      Saskatchewan  0.018692  0.036585         1.789378
# 5        5      5           Alberta  0.093458  0.146341         5.288352
# 6        6      6  British Columbia  0.154206  0.219512         6.530659
#
#        color
# 0  lightblue
# 1  lightblue
# 2       pink
# 3       pink
# 4       pink
# 5       pink
# 6       pink
